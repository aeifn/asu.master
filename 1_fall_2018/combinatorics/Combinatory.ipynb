# %% [markdown]
# ### + Задача 1.1
# Сколькими способами $20$ спортсменов могут разбиться на две команды для игры в футбол и регби, при условии, что в каждой команде не менее $9$ участников, причем футбольная команда выбирает футболки одного из трех цветов, а команда по регби — одного из двух цветов?

# %% [markdown]
# Первая команда может состоять из 9, 10, 11 человек.
# Тогда всего различных конфигураций команд $\binom{20}{9}+\binom{20}{10}+\binom{20}{11}$.
# Для каждой конфигурации возможны $2\dot3=6$ выборов футболок.
#
# **Ответ:** $6(\binom{20}{9}+\binom{20}{10}+\binom{20}{11})$.
#
# *Какие комбинаторные принципы можно применить в этой задаче?*
#
# **Ответ:** Сложение и умножение.

# %% [markdown]
# ### + Задача 1.2
# Каждая из 13 букв в слове "КОМБИНАТОРИКА" напечатана на кубике, все кубики имеют разные цвета. Сколькими способами можно разместить эти кубики в ряд, так что снова получится исходное слово?

# %% [markdown]
# С точки зрения постановки задачи, слово КОМБИНАТОРИКА не отличается от слова КК ОО М Б ИИ Н АА Т Р. Мы можем делать перестановки только одинаковых букв между собой. Единичные буквы остаются на месте. Для каждой перестановки одних букв существуют перестановки других.
#
# **Ответ:** $2^4$

# %% [markdown]
# ### + Задача 1.3
# 12 студентов писали контрольную работу из трех задач, при этом первую задачу решили 8 студентов, вторую --- 7 студентов и третью — 6 студентов. Известно также, что 6 студентов решили по две задачи, причем трое из них решили задачи с номерами 1 и 2.

# %% [markdown]
# *а) сколько студентов решили все три задачи?*
#
# Обозначим количество таких студентов за $X_3$. 6 студентов решили по две задачи, значит три задачи могли решить не более чем 6 оставшихся студентов: $X_3\le6$.
# Первые шесть студентов вместе дали 12 верных решений, а всего в результате было подано 21 верное решение (далее --- в. р.).
# Значит, другие 6 студентов дали 9 в. р. вместе. (1)
# Тогда $X_3\le3$.
# Предположим, что никто из 6 студентов не решил все три задачи. Тогда пусть они все решили по одной задаче. Общее количество в. р. будет 6. Противоречие утв. (1), значит $X_3\ge1$.
# Пусть, $X_3=1$, тогда общее количество в. р. будет $5+3=8$. Противоречие утв. (1). Значит, $2\le{X_3}\le3$.
# Пусть $X_3=2$. Тогда оставшимся 4 студентам нужно набрать 3 балла.
# Итак, возможно два расклада: $X_3=2, X_2=6, X_1=3, X_0=1$ (C1) или $X_3=3, X_2=6, X_{1,0}=0$ (C2).
# C1: Исключим из рассмотрения 2 студентов, решивших 3 задачи и троих, решивших 1 и 2 задачи. Останется распределить 1-ю задачу между $8-2-3=3$, вторую --- между $7-2-3=2$, третью между $6-2=4$ из $12-2-3-1=6$ студентов.
# Трое решили две задачи, трое одну и один ни одной.
# Пусть f отображает задачи $t_n$ в количество решивших их студентов, тогда
# $f: t_1\mapsto3, t_2\mapsto2, t_3\mapsto4$ при $X_2=3, X_1=3$
#
# Мне удалось построить такую конфигурацию.
#
# **Ответ** Все три задачи решили 2 студента.
#
# **Ответ б)** 0 задач решил один студент.
#
# **Ответ в)** 2 и 3 решил только один студент.
#
# **Ответ г)** Вся группа решила 21 балл

# %% [markdown]
# ### + Задача1.4
# Рассмотрим семейство бинарных деревьев с корнем. Каждый узел $\nu$ такого дерева можно задать парой $\nu = (\lambda,  \rho)$, где $\lambda$ — левое поддерево, $\rho$ — правое поддерево (каждое из этих двух поддеревьев может отсутствовать).
# Выведите рекуррентную формулу для числа бинарных деревьев с $n$ вершинами, используя принципы сложения и умножения.

# %% [markdown]
# Известны число деревьев $f(n)$ с количеством узлов $(n-1),(n-2),...,0$. Для дерева с $n$ узлами число деревьев будет: $f(n)=f(n-1) \cdot f(0)+f(n-2) \cdot f(2)+f(n-3) \cdot f(3)+...+f(0) \cdot f(n-1)$ или $f(n)=\sum\limits_{k=0}^{n-1} f(k)f(n-1-k)$

# %% [markdown]
# ### Задача 1.5
# Рассмотрите следующие комбинаторные схемы и вычислите общее число конфигураций:

# %% [markdown]
# *1) Сколько существует способов разделить $n$ объектов на $m$ групп заданной мощности $r_1,...,r_m$?*
#
# $\prod\limits_{k=0, l=1}^{\sum r_n, m} \binom{n-k}{r_l}$

# %% [markdown]
# ? *2). Сколькими способами можно разделить $n$ яблок по $m$ корзинам?*
#
# m способов n яблок в k-й корзине
# +
# m способов n-1 яблок в k-й корзине * m-1
# +
# m

# %% [markdown]
# ? *3). Сколькими способами можно разложить $n$ блинов по $m$ тарелкам?*
#
# Тут важен порядок. Столько же, сколько в 2), только нужно увеличить на количество перестановок в каждом случае.

# %% [markdown]
# ### ??? Задача 1.6 *
#
# Оператор $A_{n\times n}$ имеет хотя бы одну жорданову клетку размера $\ge2$. Даны $\upsilon_1,...,\upsilon_n$ --- собственные вектора. Докажите, что они линейно зависимы.
#
# **Определение** Жорданова матрица — квадратная блочно-диагональная матрица над полем $\mathbb{K}$ с блоками вида:
#
# $
# J_\lambda=
# \begin{pmatrix}
# \lambda & 1       & 0             & \cdots & 0       & 0      \\
# 0           & \lambda & 1             & \cdots & 0       & 0      \\
# 0           & 0       & \lambda       & \ddots & 0       & 0      \\
# \vdots   & \vdots  & \ddots     & \ddots & \ddots  & \vdots \\
# 0           & 0       & 0             & \ddots & \lambda & 1      \\
# 0           & 0       & 0             & \cdots & 0       & \lambda \\\end{pmatrix}$

# %% [markdown]
# ### ??? Задача 1.7 *
# Известно, что векторы $\upsilon_1,...,\upsilon_{n+1}\ne0$ являются некоторыми собственными векторами оператора $A: \mathbb{R}^n \to \mathbb{R}^n$. Кроме того, известно, что любые $n$ среди этих векторов линейно зависимы. Что можно сказать об операторе $A$?

# %% [markdown]
# **Определение** Собственный вектор --- понятие в линейной алгебре, определяемое для квадратной матрицы или произвольного линейного преобразования как ненулевой вектор, умножение матрицы на который или применение к которому преобразования даёт коллинеарный вектор --- тот же вектор, умноженный на некоторое скалярное значение, называемое собственным числом матрицы или линейного преобразования.
#
# **Определение** Оператор --- отображения (в особенности линейные) векторных пространств (проекторы, повороты координат, гомотетии, умножения вектора на матрицу).

# %% [markdown]
# ## Занятия 3, 4

# %% [markdown]
# ### + Задача 2.1
#
# Вычислить производную порядка $m$ для функции: а) $t^n$, б) $\frac{1}{1-t}$
#
# а). **Ответ:** $n!t^{n-m}, n \ge m$

# %% [markdown]
# б). $f(t)=\frac{1}{1-t}=(1-t)^{-1}$

# %% [markdown]
# $f'(t)=-1(1-t)^{-2}(-1)=(1-t)^{-2}$

# %% [markdown]
# $f''(t)=-2(1-t)^{-3}(-1)=2(t-1)^{-3}$

# %% [markdown]
# **Ответ:** $f^{(n)}(t)=n!(t-1)^{-1-n}$

# %% [markdown]
# ### + Задача 2.2
# Вычислите производящую функцию
#
# $f(t)=x_0+x_1t+x_2t^2+...$
#
# для последовательности $x_n$, удовлетворяющей следующим условиям:
#
# 1) $x_n=2x_{n-1}-x_{n-2}, x_0=0, x_1=1$
# 2) $x_n=-x_{n-1}-x_{n-2}-x_{n-3}, x_0=1,x_1=0,x_2=0$

# %% [markdown]
# 1)
# Задано рекуррентное соотношение порядка $2$:
#
# $
# x_0=0\\
# x_1=1\\
# x_n=2x_{n-1}-x_{n-2}\\
# $

# %% [markdown]
# $f(t)=x_0t^0 + x_1t^1 + \sum\limits_{n=2}^{\infty} x_n t^n$ $\ \ (1)$

# %% [markdown]
# $f(t) = t + \sum\limits_{n=2}^{\infty} 2x_{n-1}t^n - \sum\limits_{n=2}^{\infty} x_{n-2}t^n$

# %% [markdown]
# *sum a:*
# $\sum\limits_{n=2}^{\infty} 2x_{n-1}t^n =
# 2t\sum\limits_{n=2}^{\infty} x_{n-1}t^{n-1}=
# 2t\sum\limits_{n=1}^{\infty} x_{n}t^{n}
# $

# %% [markdown]
# $=2t(\sum\limits_{n=1}^{\infty} + x_0 - x_0) = 2tf(t)$

# %% [markdown]
# *sum b:* $\sum\limits_{n=2}^{\infty} x_{n-2}t^n=t^2\sum\limits_{n=0}^{\infty} x_0t^n = t^2f(t)$

# %% [markdown]
# Тогда $f(t)=t + 2tf(t) - t^2f(t)$

# %% [markdown]
# $f(t) - 2tf(t) + t^2f(t)=t$

# %% [markdown]
# **Ответ:** $f(t)=\frac{t}{t^2 - 2t + 1}$

# %% [markdown]
# 2). Задано рекуррентное соотношение подядка 3:
#
# $x_0 = 1\\
# x_1 = 0\\
# x_2 = 0\\
# x_n=-x_{n-1}-x_{n-2}-x_{n-3}
# $

# %% [markdown]
# $f(t)=1 + 0 + 0 + \sum\limits_{n=3}^{\infty} (-x_{n-1} -x_{n-2} -x_{n-3})t^n$

# %% [markdown]
# (1)=> $t\sum\limits_{n=2}^{\infty} x_nt^n = t(ft-1)$

# %% [markdown]
# (2) => $t^2(ft-1)$
# (3) => $t^3ft$

# %% [markdown]
# $ft=1-tft+t-t^2ft+t-t^3ft$

# %% [markdown]
# $ft+tft+t^2ft+t^3ft=1+2t$

# %% [markdown]
# **Ответ:** $ft=\frac{1+2t}{t^3+t^2+t+1}$

# %% [markdown]
# ### ++- Задача 2.3
# Вычислите сумму ряда $\sum\limits_{n=0}^{\infty} \frac{n}{5^n}$

# %% [markdown]
# в) методом дискретного дифференцирования
#
# $\nabla= \frac{n}{5^n}-\frac{n-1}{5^{n-1}}= $

# %% [markdown]
# $= \frac{n-5n-5}{5^n}$
#
# $\lim\limits_{n\to\infty}\frac{n-5n-5}{5^n} = 0$

# %% [markdown]
# а) методом рекурсии

# %% [markdown]
# let $x = \sum na^n$

# %% [markdown]
# $x = a + \sum (n+1)a^{n+1}$

# %% [markdown]
# $x = a + a\sum (n+1)a^{n}$

# %% [markdown]
# $x = a + a\sum na^n + a\sum a^n$

# %% [markdown]
# $x = a + ax + a\frac{a}{1-a}$

# %% [markdown]
# $x=\frac{a}{(1-a)^2}$

# %% [markdown]
# б) методом дифференцирования по $t$ производящей функции

# %% [markdown]
# Запишем в общем виде:
#
# $f(t) = \sum\limits_{n=0}^{\infty} nt^n$

# %% [markdown]
# $f(t)=a\sum\limits_{n=0}^{\infty} nt^{n-1}$

# %% [markdown]
# $\sum nt^{n-1} = (\sum t^n)'$

# %% [markdown]
# $(\frac{1}{1-t})' = \frac{1}{(1-t)^2}$

# %% [markdown]
# **Ответ:** $f(t)=\frac{a}{(1-t)^2}$

# %% [markdown]
# ### Задача 2.4
# Вычислите сумму ряда $\sum\limits_{n=0}^{\infty} \frac{n^5}{5^n}$ применяя биномиальный базис $e_k(n)=\binom{n}{k}$

# %% [markdown]
# $\sum_{k=0}^d a_k \binom{t}{k}$
#
# $a_k = \sum_{i=0}^k (-1)^{k-i} \binom{k}{i} p(i)$

# %% [markdown]
# ### ??? Задача 2.5
#
# Докажите Г-*множество* для биномиальных коэффициентов:
#
# (1) $\binom{n}{0}+\binom{n+1}{1}+\binom{n+2}{2}+...+\binom{n+m}{m}=\binom{n+m+1}{m}$
#
# (2) $\binom{n}{n}+\binom{n+1}{n}+\binom{n+2}{n}+...+\binom{n+m}{m}=\binom{n+m+1}{n+1}$
#
# иными словами, если дана фигура - ломаная в форме буквы Г в графе Паскаля, опирающаяся (под прямым углом) на границу треугольника и состоящая из отрезка длины m (длина кривой на графе исчисляется в количестве ребер графа) и отрезка длины 1 (*изобразите конфигурацию на рисунке!*), то сумма коэффициентов вдоль длинного отрезка ломаной равна биномиальному коэффициенту в крайней вершине ломаной.

# %% [markdown]
# ### ? Задча 2.6
#
# Вычислите $\int\limits_{0}^{\pi} sin^6xdx$

# %% [markdown]
# $sin^6x=(\frac{e^{ix}-e^{-ix}}{2i})^6=\frac{1}{(2i)^6} (e^{ix}+(-e^{-ix}))^6$

# %% [markdown]
# $= \frac{1}{2^6} ( e^{6ix} - 6e^{4ix} + \binom{6}{2} e^{2ix} - \binom{6}{3} 1 + \binom{6}{4} e^{-ix} - 6 e^{-3ix} + e^{-6ix} )$

# %% [markdown]
# $=\frac{1}{2^6} (cos6x+isin6x-6cos4x-6isin4x+15cos2x+15isin2x-\binom{6}{3}+15cosx-15isinx-6cos3x+6isin3x+cos6x-isin6x)$

# %% [markdown]
# Возьмем интеграл
# $\frac{1}{6} \int_0^\pi -\binom{6}{3} + 15cosx - 15isinx $

# %% [markdown]
# $=\frac{1}{2^6} (-20-30i+4i)$

# %% [markdown]
# ### Задача 2.7
#
# Пусть $n=64$. Вычислите
#
# а). $\binom{n}{1}+\binom{n}{3}+\binom{n}{5}+...+\binom{n}{n-1}$
#
# б). $\binom{n}{0}-\binom{n}{2}+\binom{n}{5}+...+(-1)^{1+\frac{n}{2}}\binom{n}{n-1}$
#
# в). $\binom{n}{1}-\binom{n}{3}+\binom{n}{5}+...+(-1)^{\frac{n}{2}}\binom{n}{n-1}$

# %% [markdown]
# ### Задача 2.8
#
# Верно ли, что для любого $k$ выполнено следующее:
#
# $\frac{\binom{2n}{n+k+1}}{\binom{2n}{m+k}}\to1, n\to+\infty$?

# %% [markdown]
# ### Задача 2.9*
#
# Изобразите несколько уровней треугольника Паскаля и подпишите вершины значениями $\gamma_n^k$, удовлетворяющая фундаментальному тождеству $\gamma_n^k=\gamma_{n-1}^{k-1}+\gamma_{n-1}^{k}$, а также краевым условиям  $\gamma_n^0=1, \gamma_n^n=-1$.

# %% [markdown]
# ### Задача 2.10*
#
# Вычислите и изобразите на графе Паскаля значения: а) $\binom{n}{k} (mod 2)$, б) $\binom{n}{k} (mod 3)$ (*задание рекомендуется выполнять с использованием компьютера*)

# %% [markdown]
# # Листок 5

# %% [markdown]
# Вычислите последовательность xn, заданную рекуррентным соотношением:
#
# 2) $x_n = 4x_{n-1} − 3x_{n-2}, x_0 = 1$

# %% [markdown]
# $1\\
# a\\
# 4a-3\\
# 4(4a-1)-3a\\
# 4(4(4(a-1)-3a)-3(4a-3)\\
# $
